# %% [markdown]
# Q1. A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
#
# - 1 Answer
# - Sales : 10+12+11+15+14+13+12 = 87
#
# Days : 7
#
#
# Calculation = 87/7 = 12.43 (12)
#
# - Weekly most representative value is 12. the mean provides the most balannced "middle ground" for the entire week's sales.
#
# Q2. A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#
# - 2 Answer
# - Stundents = 7
#
#   Marks = 12+15+14+16+18+20+19 = 114
#
#   Calculations = 114/7 = 16.29
#
# - the mean represents the average performance of the class. it allow the teacher to see the general level of understanding and provides a benchmark to compare individual student scores against.
#
# Q3. A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#
# - 3 Answer
# - Size appears:-
#
#         Size 7  appears 2 times
#
#         Size 8  appears 3 times
#
#         Size 9  appears 2 times
#
#         Size 10 appears 1 times
#
#
# - The mode is Size 8, beacuse it appears more often than any other size.
# - since size 8 is the most popular, the manager knows they need to order more stock of size 8 compared to size 10 to avoid running out. it helps the manager understand customers needs.
#
# Q4. A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.
#
# - 4 Answer
# - Median = 10,200
# - The Value $ 50,000 is much higher than the rest. The median is resistant to outliers and gives a better sense of the central price.
#
# Q5. A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
#
# - 5 Answer
# - The range is the difference between the maximum and minimum values: 40-25 = 15.
# - The range tells us the total spread of the stundent's performance. The student isn't perfectly consistent, as their fastest time is significantly quicker than their slowest time.
#
# Q6. A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120]. Find the range. How can this help the farmer in planning his packaging?
#
# - 6 Answer
# - Find the Range
#
#   Maximum = 120, Minimum = 98
#
#   Range = 120 - 98 = 22kg
#
# - Understanding the range helps the farmer determine the minimum and maximum capacity needed for his equipment. He knows he needs enough packaging to handle at least 120 kg per week, and he can predict that his harvest won’t likely drop below 98 kg, allowing for better inventory management of packaging.
#
# Q7. Variance for Decision-Making (Medium)
# Two delivery companies track delivery delays (in minutes).
#
# Company A: variance = 6
#
# Company B: variance = 15
#
#
#  Which company is more consistent, and why?
#
# - 7 Answer
# - Company A is more consistent.
# - In statistics, variance measures how far a set of numbers are spread out form their average value. a lower variance means the data points are closer to the mena, indicating higher reliabilty and predictabilty. Company B has much higher fluctuations in its delivery delays.
#
# Q8. A finance student compares the daily price fluctuations of two cryptocurrencies.
#
# Coin A: standard deviation = $30
#
# Coin B: standard deviation = $120
#  Which coin is riskier to invest in, and why?
#
# - 8 Answer
# - Coin B is the riskier investment
# - The Price of coin B moves in the wider range, there is a higher probabiltiy losses in a short period.
#
# Q9. A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410].
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use pattern?
#
# - 9 Answer
# - The Standard Deviation (20.59 kWh)
# - The family has a consistent energy use pattern because the standard deviation is small, there are no massive spikes or drops in usage; they likely follow a stable routine. they dont have seasonal equipments too so that their bill will increase.
#
# Q10.  A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide about the player’s scoring performance?
#
# - 10 Answer
# - Mean:-  15+17+18+19+20+21+22+25 = 157
#
#         157/8 = 19.625
# - Median:- 19+20 = 49
#
#          49/2 = 19.5
# - Mode:- None
#
# - Range:- 25-15 = 10
#
# - Standard Deviation:- = 2.95
#
# - The Range of 10 points shows that even on their "worst" and "best" days, their performance stays within predictable window 15 to 25 points.
